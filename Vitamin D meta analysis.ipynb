# %%
from lxml import etree
from lxml import objectify

# %%
cr = etree.parse("CD007470StatsDataOnly.rm5")
#pulls out all the studies with low risk of bias
root = cr.getroot()
ad = root.getchildren()[7]
a = ad.getchildren()[0].getchildren()[1].getchildren()
studies_xml = a[5].getchildren()[1:]#+ a[6].getchildren()[1:]

def toNumber(v): 
    try: 
        return float(v) 
    except Exception: 
        return v
    
def asNumbers(d): 
    return { k : toNumber(v) for k,v in d.items()}


stds = [asNumbers(dict(s.attrib)) for s in studies_xml]
import pandas as pd 
studies = pd.DataFrame(stds)

# %%
from pymc import *

# %%
def inv_logit(p):
    return 1 /(1+ exp(-p))

with Model() as model: 
    nstudies = len(studies)
    
    #hazard rate distribution 
    hm = Normal('hm', -2.5, 3) #mean hazard rate
    sdh = Tpos('sdh', 15, 1, .5**-2)
    
    #hyperparameters for effect size distribution
    em = T('em', 8, 0, .05**-2) #mean effect size
    sd = Tpos('sd', 15, .05, .05**-2) 
    
    h = Normal('h', hm, sd = sdh, shape = nstudies)
    e = Normal('e', em, sd = sd, shape = nstudies)
    

    controls = Binomial('controls', p = inv_logit(h), n = studies.TOTAL_2.values, observed = studies.EVENTS_2.values)
    treatment = Binomial('treatment', p = inv_logit(h+e), n = studies.TOTAL_1.values, observed = studies.EVENTS_1.values)
    
    start = find_MAP(vars =[hm, em, h, e])
    step = NUTS(scaling=start)
    trace = sample(3000, step)
# Out:
#  [                  1%                  ] 51 of 3000 complete in 0.5 sec
#  [-                 3%                  ] 98 of 3000 complete in 1.0 sec
#  [-                 4%                  ] 132 of 3000 complete in 1.5 sec
#  [--                5%                  ] 171 of 3000 complete in 2.0 sec
#  [--                7%                  ] 219 of 3000 complete in 2.6 sec
#  [---               7%                  ] 237 of 3000 complete in 3.3 sec
#  [---               8%                  ] 244 of 3000 complete in 3.8 sec
#  [---               8%                  ] 253 of 3000 complete in 4.3 sec
#  [---               8%                  ] 262 of 3000 complete in 4.8 sec
#  [---               9%                  ] 276 of 3000 complete in 5.3 sec
#  [----             10%                  ] 321 of 3000 complete in 5.8 sec
#  [----             12%                  ] 385 of 3000 complete in 6.3 sec
#  [-----            14%                  ] 444 of 3000 complete in 6.9 sec
#  [------           16%                  ] 502 of 3000 complete in 7.4 sec
#  [-------          18%                  ] 555 of 3000 complete in 7.9 sec
#  [-------          19%                  ] 583 of 3000 complete in 8.4 sec
#  [--------         21%                  ] 652 of 3000 complete in 8.9 sec
#  [--------         22%                  ] 689 of 3000 complete in 9.4 sec
#  [---------        24%                  ] 744 of 3000 complete in 9.9 sec
#  [----------       27%                  ] 810 of 3000 complete in 10.4 sec
#  [----------       28%                  ] 852 of 3000 complete in 10.9 sec
#  [-----------      29%                  ] 896 of 3000 complete in 11.4 sec
#  [------------     31%                  ] 955 of 3000 complete in 11.9 sec
#  [------------     33%                  ] 1009 of 3000 complete in 12.4 sec
#  [-------------    35%                  ] 1063 of 3000 complete in 12.9 sec
#  [-------------    35%                  ] 1079 of 3000 complete in 13.5 sec
#  [-------------    36%                  ] 1089 of 3000 complete in 14.0 sec
#  [-------------    36%                  ] 1096 of 3000 complete in 14.6 sec
#  [-------------    36%                  ] 1101 of 3000 complete in 15.2 sec
#  [--------------   36%                  ] 1109 of 3000 complete in 15.8 sec
#  [--------------   37%                  ] 1119 of 3000 complete in 16.3 sec
#  [--------------   38%                  ] 1140 of 3000 complete in 16.8 sec
#  [--------------   38%                  ] 1158 of 3000 complete in 17.3 sec
#  [---------------  40%                  ] 1204 of 3000 complete in 17.8 sec
#  [---------------- 42%                  ] 1270 of 3000 complete in 18.3 sec
#  [---------------- 44%                  ] 1337 of 3000 complete in 18.8 sec
#  [-----------------46%                  ] 1392 of 3000 complete in 19.3 sec
#  [-----------------48%                  ] 1444 of 3000 complete in 19.8 sec
#  [-----------------50%                  ] 1505 of 3000 complete in 20.3 sec
#  [-----------------52%                  ] 1570 of 3000 complete in 20.8 sec
#  [-----------------54%                  ] 1649 of 3000 complete in 21.3 sec
#  [-----------------57%-                 ] 1713 of 3000 complete in 21.8 sec
#  [-----------------58%--                ] 1766 of 3000 complete in 22.3 sec
#  [-----------------60%---               ] 1821 of 3000 complete in 22.8 sec
#  [-----------------61%---               ] 1855 of 3000 complete in 23.4 sec
#  [-----------------62%---               ] 1886 of 3000 complete in 23.9 sec
#  [-----------------65%----              ] 1956 of 3000 complete in 24.4 sec
#  [-----------------67%-----             ] 2021 of 3000 complete in 24.9 sec
#  [-----------------69%------            ] 2077 of 3000 complete in 25.4 sec
#  [-----------------71%-------           ] 2134 of 3000 complete in 25.9 sec
#  [-----------------73%-------           ] 2195 of 3000 complete in 26.4 sec
#  [-----------------75%--------          ] 2252 of 3000 complete in 26.9 sec
#  [-----------------76%---------         ] 2309 of 3000 complete in 27.4 sec
#  [-----------------78%---------         ] 2342 of 3000 complete in 28.0 sec
#  [-----------------78%---------         ] 2364 of 3000 complete in 28.5 sec
#  [-----------------79%----------        ] 2389 of 3000 complete in 29.0 sec
#  [-----------------80%----------        ] 2405 of 3000 complete in 29.5 sec
#  [-----------------81%-----------       ] 2448 of 3000 complete in 30.0 sec
#  [-----------------83%-----------       ] 2507 of 3000 complete in 30.5 sec
#  [-----------------85%------------      ] 2559 of 3000 complete in 31.0 sec
#  [-----------------87%-------------     ] 2634 of 3000 complete in 31.5 sec
#  [-----------------88%-------------     ] 2667 of 3000 complete in 32.0 sec
#  [-----------------90%--------------    ] 2723 of 3000 complete in 32.5 sec
#  [-----------------93%---------------   ] 2794 of 3000 complete in 33.0 sec
#  [-----------------95%----------------  ] 2855 of 3000 complete in 33.6 sec
#  [-----------------96%----------------  ] 2883 of 3000 complete in 34.1 sec
#  [-----------------97%----------------- ] 2927 of 3000 complete in 34.6 sec
#  [-----------------99%----------------- ] 2980 of 3000 complete in 35.1 sec
#  [-----------------100%-----------------] 3000 of 3000 complete in 35.3 sec
# /usr/local/lib/python2.7/dist-packages/theano/scan_module/scan_perform_ext.py:85: RuntimeWarning: numpy.ndarray size changed, may indicate binary incompatibility
#   from scan_perform.scan_perform import *

# %%
traceplot(trace);

# %%
pd.DataFrame(trace['em']).
